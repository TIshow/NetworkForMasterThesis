# %%
f = open("洪水.txt", 'r')
data = f.read()
f.close()

# %%
data
# Out:
# 'a somewhat poor but honest philosopher searching for a cosmic law carried a telescope to the flat rooftop to search for the motion of the universe. Like always, he did not seem to discover any promise of a star\'s position--only any number of meaningless falling stars, and it looked like he would discern what was expected So, out of tedium, it was no wonder that he innocently turned the telescope to the ground. He saw the street below inverted in the telescope; similarly he could see a laborer walking upside down. Within his consciousness, those inverted images were returned to normal relations as he moved the lens to follow the worker\'s movement. Through the large lens, he could see through the worker\'s small head. This was because, after returning from the night shift at the factory, there was nothing but fatigue in his head. However, the patient philosopher would not turn his lens away;\nfurthermore, he continued to pursue the worker. Soon that patience was rewarded: suddenly a metamorphosis overcame the worker. His body suddenly became an opaque, meaningless profile while he crouched in slime, melting from his leg, becoming a plump mass of n1UCUS, with only his clothes, hat, and shoes left behind. Finally, the completely fluid worker spread out across the level ground. the liquefied worker quietly began to flow toward tile lower ground. He flowed into a sunken place in the road. Then he came out. The philosopher was so frightened that he almost dropped the telescope upon seeing the motion of the liquid worker going against hydrodynamic law. Flowing more and nl0re along the roadside, he ran into a wall, which he\ncrawled up like a living creature grasping on its film of slime. The philosopher let go of the telescope and breathed a heavy sigh. The next day, the philosopher predicted that a great flood was facing the world. As a matter of fact, as this announcement was about to reach society, laborers and the poor were beginning to liquefy. This collective liquefaction was especially remarkable. At the large factories, the operation of machinery suddenly came to a standstill. All at once the mass of people liquefied, forming a small stream and started to flow under the space in the doors, climbing up the walls and out the windows. The system was upset, \'finally collapsing after the workers completely liquified, for no one in the disorder within the factory could maintain the operation of the machines. Additionally, the convicts in the prisons liquified en masse, plotting an escape, and all the peasants in one village liquified, causing a small flood. One story after another was reported in the newspapers. This liquefaction of human beings was progressing fluidly: this brought about confusion on various faces. Perfect crimes were radically increasing from the liquid criminals, disturbing the public peace and order. At the police station physicists were meeting in secret to mobilizing, inquiring into the nature of this fluid. However, the liquid flowed perfectly in defiance of scientific law, causing the physicists to think that the chaos must be some sort of trick. If one tried to touch the fluid, though it did not seem even a little different from water, it would display a mercury-like surface tension, depending on the time. Because it could maintain its very own amoeba-like outline, it could do more than just climb from the low to high places, as has been mentioned before. The liquefied people, after once completely softening as per the nature of this fluid, continued dividing regardless of the amount of any stimulus they received. Still, there were times when the fluid would display an alcohol-like weak surface tension. At that time, it displayed an abnormally strong osmotic tendency against the solids it was sliding over. That is to say that even against a homogenous film, depending on the time, it was likely to vary in its responses, having quite unreactive chemical properties. The liquefied people could also freeze a ...

# %%
import re
print (re.findall(r'\w+|\S+', data))
# Out:
# ['a', 'somewhat', 'poor', 'but', 'honest', 'philosopher', 'searching', 'for', 'a', 'cosmic', 'law', 'carried', 'a', 'telescope', 'to', 'the', 'flat', 'rooftop', 'to', 'search', 'for', 'the', 'motion', 'of', 'the', 'universe', '.', 'Like', 'always', ',', 'he', 'did', 'not', 'seem', 'to', 'discover', 'any', 'promise', 'of', 'a', 'star', "'s", 'position', '--only', 'any', 'number', 'of', 'meaningless', 'falling', 'stars', ',', 'and', 'it', 'looked', 'like', 'he', 'would', 'discern', 'what', 'was', 'expected', 'So', ',', 'out', 'of', 'tedium', ',', 'it', 'was', 'no', 'wonder', 'that', 'he', 'innocently', 'turned', 'the', 'telescope', 'to', 'the', 'ground', '.', 'He', 'saw', 'the', 'street', 'below', 'inverted', 'in', 'the', 'telescope', ';', 'similarly', 'he', 'could', 'see', 'a', 'laborer', 'walking', 'upside', 'down', '.', 'Within', 'his', 'consciousness', ',', 'those', 'inverted', 'images', 'were', 'returned', 'to', 'normal', 'relations', 'as', 'he', 'moved', 'the', 'lens', 'to', 'follow', 'the', 'worker', "'s", 'movement', '.', 'Through', 'the', 'large', 'lens', ',', 'he', 'could', 'see', 'through', 'the', 'worker', "'s", 'small', 'head', '.', 'This', 'was', 'because', ',', 'after', 'returning', 'from', 'the', 'night', 'shift', 'at', 'the', 'factory', ',', 'there', 'was', 'nothing', 'but', 'fatigue', 'in', 'his', 'head', '.', 'However', ',', 'the', 'patient', 'philosopher', 'would', 'not', 'turn', 'his', 'lens', 'away', ';', 'furthermore', ',', 'he', 'continued', 'to', 'pursue', 'the', 'worker', '.', 'Soon', 'that', 'patience', 'was', 'rewarded', ':', 'suddenly', 'a', 'metamorphosis', 'overcame', 'the', 'worker', '.', 'His', 'body', 'suddenly', 'became', 'an', 'opaque', ',', 'meaningless', 'profile', 'while', 'he', 'crouched', 'in', 'slime', ',', 'melting', 'from', 'his', 'leg', ',', 'becoming', 'a', 'plump', 'mass', 'of', 'n1UCUS', ',', 'with', 'only', 'his', 'clothes', ',', 'hat', ',', 'and', 'shoes', 'left', 'behind', '.', 'Finally', ',', 'the', 'completely', 'fluid', 'worker', 'spread', 'out', 'across', 'the', 'level', 'ground', '.', 'the', 'liquefied', 'worker', 'quietly', 'began', 'to', 'flow', 'toward', 'tile', 'lower', 'ground', '.', 'He', 'flowed', 'into', 'a', 'sunken', 'place', 'in', 'the', 'road', '.', 'Then', 'he', 'came', 'out', '.', 'The', 'philosopher', 'was', 'so', 'frightened', 'that', 'he', 'almost', 'dropped', 'the', 'telescope', 'upon', 'seeing', 'the', 'motion', 'of', 'the', 'liquid', 'worker', 'going', 'against', 'hydrodynamic', 'law', '.', 'Flowing', 'more', 'and', 'nl0re', 'along', 'the', 'roadside', ',', 'he', 'ran', 'into', 'a', 'wall', ',', 'which', 'he', 'crawled', 'up', 'like', 'a', 'living', 'creature', 'grasping', 'on', 'its', 'film', 'of', 'slime', '.', 'The', 'philosopher', 'let', 'go', 'of', 'the', 'telescope', 'and', 'breathed', 'a', 'heavy', 'sigh', '.', 'The', 'next', 'day', ',', 'the', 'philosopher', 'predicted', 'that', 'a', 'great', 'flood', 'was', 'facing', 'the', 'world', '.', 'As', 'a', 'matter', 'of', 'fact', ',', 'as', 'this', 'announcement', 'was', 'about', 'to', 'reach', 'society', ',', 'laborers', 'and', 'the', 'poor', 'were', 'beginning', 'to', 'liquefy', '.', 'This', 'collective', 'liquefaction', 'was', 'especially', 'remarkable', '.', 'At', 'the', 'large', 'factories', ',', 'the', 'operation', 'of', 'machinery', 'suddenly', 'came', 'to', 'a', 'standstill', '.', 'All', 'at', 'once', 'the', 'mass', 'of', 'people', 'liquefied', ',', 'forming', 'a', 'small', 'stream', 'and', 'started', 'to', 'flow', 'under', 'the', 'space', 'in', 'the', 'doors', ',', 'climbing', 'up', 'the', 'walls', 'and', 'out', 'the', 'windows', '.', 'The', 'system', 'was', 'upset', ',', "'finally", 'collapsing', 'after', 'the', 'workers', 'completely', 'liquified', ',', 'for', 'no', 'one', 'in', 'the', 'disorder', 'within', 'the', 'factory', 'could', 'maintain', 'the', 'operation', 'of', 'the', 'machines', '.', 'Additionally', ',', 'the', 'convicts', 'in', 'the', 'prisons', 'liquified', 'en', 'masse', ',', 'p ...

# %%
# Out:
# 'a somewhat poor but honest philosopher searching for a cosmic law carried a telescope to the flat rooftop to search for the motion of the universe. Like always, he did not seem to discover any promise of a star\'s position--only any number of meaningless falling stars, and it looked like he would discern what was expected So, out of tedium, it was no wonder that he innocently turned the telescope to the ground. He saw the street below inverted in the telescope; similarly he could see a laborer walking upside down. Within his consciousness, those inverted images were returned to normal relations as he moved the lens to follow the worker\'s movement. Through the large lens, he could see through the worker\'s small head. This was because, after returning from the night shift at the factory, there was nothing but fatigue in his head. However, the patient philosopher would not turn his lens away;\nfurthermore, he continued to pursue the worker. Soon that patience was rewarded: suddenly a metamorphosis overcame the worker. His body suddenly became an opaque, meaningless profile while he crouched in slime, melting from his leg, becoming a plump mass of n1UCUS, with only his clothes, hat, and shoes left behind. Finally, the completely fluid worker spread out across the level ground. the liquefied worker quietly began to flow toward tile lower ground. He flowed into a sunken place in the road. Then he came out. The philosopher was so frightened that he almost dropped the telescope upon seeing the motion of the liquid worker going against hydrodynamic law. Flowing more and nl0re along the roadside, he ran into a wall, which he\ncrawled up like a living creature grasping on its film of slime. The philosopher let go of the telescope and breathed a heavy sigh. The next day, the philosopher predicted that a great flood was facing the world. As a matter of fact, as this announcement was about to reach society, laborers and the poor were beginning to liquefy. This collective liquefaction was especially remarkable. At the large factories, the operation of machinery suddenly came to a standstill. All at once the mass of people liquefied, forming a small stream and started to flow under the space in the doors, climbing up the walls and out the windows. The system was upset, \'finally collapsing after the workers completely liquified, for no one in the disorder within the factory could maintain the operation of the machines. Additionally, the convicts in the prisons liquified en masse, plotting an escape, and all the peasants in one village liquified, causing a small flood. One story after another was reported in the newspapers. This liquefaction of human beings was progressing fluidly: this brought about confusion on various faces. Perfect crimes were radically increasing from the liquid criminals, disturbing the public peace and order. At the police station physicists were meeting in secret to mobilizing, inquiring into the nature of this fluid. However, the liquid flowed perfectly in defiance of scientific law, causing the physicists to think that the chaos must be some sort of trick. If one tried to touch the fluid, though it did not seem even a little different from water, it would display a mercury-like surface tension, depending on the time. Because it could maintain its very own amoeba-like outline, it could do more than just climb from the low to high places, as has been mentioned before. The liquefied people, after once completely softening as per the nature of this fluid, continued dividing regardless of the amount of any stimulus they received. Still, there were times when the fluid would display an alcohol-like weak surface tension. At that time, it displayed an abnormally strong osmotic tendency against the solids it was sliding over. That is to say that even against a homogenous film, depending on the time, it was likely to vary in its responses, having quite unreactive chemical properties. The liquefied people could also freeze a ...

# %%
data2 = re.findall(r'\w+|\S+', data)

# %%
data2
# Out:
# ['a',
#  'somewhat',
#  'poor',
#  'but',
#  'honest',
#  'philosopher',
#  'searching',
#  'for',
#  'a',
#  'cosmic',
#  'law',
#  'carried',
#  'a',
#  'telescope',
#  'to',
#  'the',
#  'flat',
#  'rooftop',
#  'to',
#  'search',
#  'for',
#  'the',
#  'motion',
#  'of',
#  'the',
#  'universe',
#  '.',
#  'Like',
#  'always',
#  ',',
#  'he',
#  'did',
#  'not',
#  'seem',
#  'to',
#  'discover',
#  'any',
#  'promise',
#  'of',
#  'a',
#  'star',
#  "'s",
#  'position',
#  '--only',
#  'any',
#  'number',
#  'of',
#  'meaningless',
#  'falling',
#  'stars',
#  ',',
#  'and',
#  'it',
#  'looked',
#  'like',
#  'he',
#  'would',
#  'discern',
#  'what',
#  'was',
#  'expected',
#  'So',
#  ',',
#  'out',
#  'of',
#  'tedium',
#  ',',
#  'it',
#  'was',
#  'no',
#  'wonder',
#  'that',
#  'he',
#  'innocently',
#  'turned',
#  'the',
#  'telescope',
#  'to',
#  'the',
#  'ground',
#  '.',
#  'He',
#  'saw',
#  'the',
#  'street',
#  'below',
#  'inverted',
#  'in',
#  'the',
#  'telescope',
#  ';',
#  'similarly',
#  'he',
#  'could',
#  'see',
#  'a',
#  'laborer',
#  'walking',
#  'upside',
#  'down',
#  '.',
#  'Within',
#  'his',
#  'consciousness',
#  ',',
#  'those',
#  'inverted',
#  'images',
#  'were',
#  'returned',
#  'to',
#  'normal',
#  'relations',
#  'as',
#  'he',
#  'moved',
#  'the',
#  'lens',
#  'to',
#  'follow',
#  'the',
#  'worker',
#  "'s",
#  'movement',
#  '.',
#  'Through',
#  'the',
#  'large',
#  'lens',
#  ',',
#  'he',
#  'could',
#  'see',
#  'through',
#  'the',
#  'worker',
#  "'s",
#  'small',
#  'head',
#  '.',
#  'This',
#  'was',
#  'because',
#  ',',
#  'after',
#  'returning',
#  'from',
#  'the',
#  'night',
#  'shift',
#  'at',
#  'the',
#  'factory',
#  ',',
#  'there',
#  'was',
#  'nothing',
#  'but',
#  'fatigue',
#  'in',
#  'his',
#  'head',
#  '.',
#  'However',
#  ',',
#  'the',
#  'patient',
#  'philosopher',
#  'would',
#  'not',
#  'turn',
#  'his',
#  'lens',
#  'away',
#  ';',
#  'furthermore',
#  ',',
#  'he',
#  'continued',
#  'to',
#  'pursue',
#  'the',
#  'worker',
#  '.',
#  'Soon',
#  'that',
#  'patience',
#  'was',
#  'rewarded',
#  ':',
#  'suddenly',
#  'a',
#  'metamorphosis',
#  'overcame',
#  'the',
#  'worker',
#  '.',
#  'His',
#  'body',
#  'suddenly',
#  'became',
#  'an',
#  'opaque',
#  ',',
#  'meaningless',
#  'profile',
#  'while',
#  'he',
#  'crouched',
#  'in',
#  'slime',
#  ',',
#  'melting',
#  'from',
#  'his',
#  'leg',
#  ',',
#  'becoming',
#  'a',
#  'plump',
#  'mass',
#  'of',
#  'n1UCUS',
#  ',',
#  'with',
#  'only',
#  'his',
#  'clothes',
#  ',',
#  'hat',
#  ',',
#  'and',
#  'shoes',
#  'left',
#  'behind',
#  '.',
#  'Finally',
#  ',',
#  'the',
#  'completely',
#  'fluid',
#  'worker',
#  'spread',
#  'out',
#  'across',
#  'the',
#  'level',
#  'ground',
#  '.',
#  'the',
#  'liquefied',
#  'worker',
#  'quietly',
#  'began',
#  'to',
#  'flow',
#  'toward',
#  'tile',
#  'lower',
#  'ground',
#  '.',
#  'He',
#  'flowed',
#  'into',
#  'a',
#  'sunken',
#  'place',
#  'in',
#  'the',
#  'road',
#  '.',
#  'Then',
#  'he',
#  'came',
#  'out',
#  '.',
#  'The',
#  'philosopher',
#  'was',
#  'so',
#  'frightened',
#  'that',
#  'he',
#  'almost',
#  'dropped',
#  'the',
#  'telescope',
#  'upon',
#  'seeing',
#  'the',
#  'motion',
#  'of',
#  'the',
#  'liquid',
#  'worker',
#  'going',
#  'against',
#  'hydrodynamic',
#  'law',
#  '.',
#  'Flowing',
#  'more',
#  'and',
#  'nl0re',
#  'along',
#  'the',
#  'roadside',
#  ',',
#  'he',
#  'ran',
#  'into',
#  'a',
#  'wall',
#  ',',
#  'which',
#  'he',
#  'crawled',
#  'up',
#  'like',
#  'a',
#  'living',
#  'creature',
#  'grasping',
#  'on',
#  'its',
#  'film',
#  'of',
#  'slime',
#  '.',
#  'The',
#  'philosopher',
#  'let',
#  'go',
#  'of',
#  'the',
#  'telescope',
#  'and',
#  'breathed',
#  'a',
#  'heavy',
#  'sigh',
#  '.',
#  'The',
#  'next',
#  'day',
#  ',',
#  'the',
#  'philosopher',
#  'predicted',
#  'that',
#  'a',
#  'great',
#  'flood',
#  'was',
#  'facing',
#  'the',
#  'world',
#  '.',
#  'As',
#  'a',
#  'matter',
#  'of',
#  'fact',
#  ',',
#  'as',
#  'this',
#  'announcement',
#  'was',
#  'about',
#  'to',
#  'reach',
#  'society',
#  ',',
#  'laborers',
#  'and',
#  'the',
#  'poor',
#  'were',
#  'beginning',
#  'to',
#  'liquefy',
#  '.',
#  'This',
#  'collective',
#  'liquefaction',
#  'was',
#  'especially',
#  'remarkable',
#  '.',
#  'At',
#  'the',
#  'large',
#  'factories',
#  ',',
#  'the',
#  'operation',
#  'of',
#  'machinery',
#  'suddenly',
#  'came',
#  'to',
#  'a',
#  'standstill',
#  '.',
#  'All',
#  'at',
#  'once',
#  'the',
#  'mass',
#  'of',
#  'people',
#  'liquefied',
#  ',',
#  'forming',
#  'a',
#  'small',
#  'stream',
#  'and',
#  'started',
#  'to',
#  'flow',
#  'under',
#  'the',
#  'space',
#  'in',
#  'the',
#  'doors',
#  ',',
#  'climbing',
#  'up',
#  'the',
#  'walls',
#  'and',
#  'out',
#  'the',
#  'windows',
#  '.',
#  'The',
#  'system',
#  'was',
#  'upset',
#  ',',
#  "'finally",
#  'collapsing',
#  'after',
#  'the',
#  'workers',
#  'completely',
#  'liquified',
#  ',',
#  'for',
#  'no',
#  'one',
#  'in',
#  'the',
#  'disorder',
#  'within',
#  'the',
#  'factory',
#  'could',
#  'maintain',
#  'the',
#  'operation',
#  'of',
#  'the',
#  'machines',
#  '.',
#  'Additionally',
#  ',',
#  'the',
#  'convicts',
#  'in',
#  'the',
#  'prisons',
#  'liquified',
#  'en',
#  'masse',
#  ',',
#  'plotting',
#  'an',
#  'escape',
#  ',',
#  'and',
#  'all',
#  'the',
#  'peasants',
#  'in',
#  'one',
#  'village',
#  'liquified',
#  ',',
#  'causing',
#  'a',
#  'small',
#  'flood',
#  '.',
#  'One',
#  'story',
#  'after',
#  'another',
#  'was',
#  'reported',
#  'in',
#  'the',
#  'newspapers',
#  '.',
#  'This',
#  'liquefaction',
#  'of',
#  'human',
#  'beings',
#  'was',
#  'progressing',
#  'fluidly',
#  ':',
#  'this',
#  'brought',
#  'about',
#  'confusion',
#  'on',
#  'various',
#  'faces',
#  '.',
#  'Perfect',
#  'crimes',
#  'were',
#  'radically',
#  'increasing',
#  'from',
#  'the',
#  'liquid',
#  'criminals',
#  ',',
#  'disturbing',
#  'the',
#  'public',
#  'peace',
#  'and',
#  'order',
#  '.',
#  'At',
#  'the',
#  'police',
#  'station',
#  'physicists',
#  'were',
#  'meeting',
#  'in',
#  'secret',
#  'to',
#  'mobilizing',
#  ',',
#  'inquiring',
#  'into',
#  'the',
#  'nature',
#  'of',
#  'this',
#  'fluid',
#  '.',
#  'However',
#  ',',
#  'the',
#  'liquid',
#  'flowed',
#  'perfectly',
#  'in',
#  'defiance',
#  'of',
#  'scientific',
#  'law',
#  ',',
#  'causing',
#  'the',
#  'physicists',
#  'to',
#  'think',
#  'that',
#  'the',
#  'chaos',
#  'must',
#  'be',
#  'some',
#  'sort',
#  'of',
#  'trick',
#  '.',
#  'If',
#  'one',
#  'tried',
#  'to',
#  'touch',
#  'the',
#  'fluid',
#  ',',
#  'though',
#  'it',
#  'did',
#  'not',
#  'seem',
#  'even',
#  'a',
#  'little',
#  'different',
#  'from',
#  'water',
#  ',',
#  'it',
#  'would',
#  'display',
#  'a',
#  'mercury',
#  '-like',
#  'surface',
#  'tension',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'time',
#  '.',
#  'Because',
#  'it',
#  'could',
#  'maintain',
#  'its',
#  'very',
#  'own',
#  'amoeba',
#  '-like',
#  'outline',
#  ',',
#  'it',
#  'could',
#  'do',
#  'more',
#  'than',
#  'just',
#  'climb',
#  'from',
#  'the',
#  'low',
#  'to',
#  'high',
#  'places',
#  ',',
#  'as',
#  'has',
#  'been',
#  'mentioned',
#  'before',
#  '.',
#  'The',
#  'liquefied',
#  'people',
#  ',',
#  'after',
#  'once',
#  'completely',
#  'softening',
#  'as',
#  'per',
#  'the',
#  'nature',
#  'of',
#  'this',
#  'fluid',
#  ',',
#  'continued',
#  'dividing',
#  'regardless',
#  'of',
#  'the',
#  'amount',
#  'of',
#  'any',
#  'stimulus',
#  'they',
#  'received',
#  '.',
#  'Still',
#  ',',
#  'there',
#  'were',
#  'times',
#  'when',
#  'the',
#  'fluid',
#  'would',
#  'display',
#  'an',
#  'alcohol',
#  '-like',
#  'weak',
#  'surface',
#  'tension',
#  '.',
#  'At',
#  'that',
#  'time',
#  ',',
#  'it',
#  'displayed',
#  'an',
#  'abnormally',
#  'strong',
#  'osmotic',
#  'tendency',
#  'against',
#  'the',
#  'solids',
#  'it',
#  'was',
#  'sliding',
#  'over',
#  '.',
#  'That',
#  'is',
#  'to',
#  'say',
#  'that',
#  'even',
#  'against',
#  'a',
#  'homogenous',
#  'film',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'time',
#  ',',
#  'it',
#  'was',
#  'likely',
#  'to',
#  'vary',
#  'in',
#  'its',
#  'responses',
#  ',',
#  'having',
#  'quite',
#  'unreactive',
#  'chemical',
#  'properties',
#  '.',
#  'The',
#  'liquefied',
#  'people',
#  'could',
#  'also',
#  'freeze',
#  'and',
#  'evaporate',
#  '.',
#  'The',
#  'freezing',
#  'point',
#  'and',
#  'point',
#  'of',
#  'vaporization',
#  'were',
#  'diverse',
#  '.',
#  'Thus',
#  ',',
#  'sleds',
#  'running',
#  'on',
#  'thick',
#  'ice',
#  'were',
#  'beginning',
#  'to',
#  'sink',
#  'one',
#  'by',
#  'one',
#  ',',
#  'or',
#  'suddenly',
#  'the',
#  'swift',
#  'lead',
#  'skater',
#  'in',
#  'a',
#  'race',
#  'would',
#  'vanish',
#  '.',
#  'Also',
#  ',',
#  'in',
#  'midsummer',
#  'the',
#  'pools',
#  'rapidly',
#  'evaporated',
#  ',',
#  'and',
#  'young',
#  'women',
#  'swimming',
#  'were',
#  'occasionally',
#  'completely',
#  'encased',
#  'in',
#  'ice',
#  '.',
#  'The',
#  'liquid',
#  'people',
#  'were',
#  'clirnbing',
#  'the',
#  'mountains',
#  ',',
#  'getting',
#  'mixed',
#  'with',
#  'the',
#  'rivers',
#  ',',
#  'crossing',
#  'the',
#  'oceans',
#  ',',
#  'becoming',
#  'clouds',
#  'of',
#  'steam',
#  ',',
#  'and',
#  'becoming',
#  'rainfalls',
#  ',',
#  'spreading',
#  'out',
#  'throughout',
#  'a',
#  'world',
#  'completely',
#  'unprepared',
#  'for',
#  'such',
#  'an',
#  'occurrence',
#  '.',
#  'Chemistry',
#  'experiments',
#  'fell',
#  'into',
#  'an',
#  'almost',
#  'impossible',
#  'state',
#  'of',
#  'affairs',
#  '.',
#  'The',
#  'boilers',
#  'of',
#  'steam',
#  'locomotives',
#  'did',
#  'not',
#  'withstand',
#  'the',
#  'aggressive',
#  'mingling',
#  'of',
#  'the',
#  'liquefied',
#  'people',
#  '.',
#  'No',
#  'matter',
#  'how',
#  'much',
#  'one',
#  'boiled',
#  ',',
#  'the',
#  'pressure',
#  'would',
#  'not',
#  'increase',
#  ';',
#  'then',
#  'the',
#  'boiler',
#  'would',
#  'expand',
#  'radically',
#  'and',
#  'explode',
#  '.',
#  'The',
#  'effect',
#  'the',
#  'fluid',
#  'had',
#  'upon',
#  'ichthyology',
#  'and',
#  'marine',
#  'botany',
#  'was',
#  'beyond',
#  'words',
#  '.',
#  'For',
#  'whatever',
#  'biological',
#  'reason',
#  ',',
#  'immeasurable',
#  'changes',
#  'and',
#  'extinctions',
#  'were',
#  'beginning',
#  '.',
#  'Singing',
#  ',',
#  'writhing',
#  'apples',
#  ',',
#  'erupting',
#  'rice',
#  'plants',
#  'that',
#  'raised',
#  'a',
#  'sound',
#  'like',
#  'fireworks',
#  ',',
#  'and',
#  'other',
#  'new',
#  'botanical',
#  'varieties',
#  'were',
#  'discovered',
#  '.',
#  'Particularly',
#  'serious',
#  'were',
#  'the',
#  'effects',
#  'on',
#  'those',
#  'people',
#  'still',
#  'not',
#  'liquified',
#  ',',
#  'most',
#  'of',
#  'whom',
#  'were',
#  'especially',
#  'wealthy',
#  'people',
#  '.',
#  'One',
#  'morning',
#  'a',
#  'factory',
#  'foreman',
#  'tried',
#  'to',
#  'take',
#  'a',
#  'sip',
#  'from',
#  'his',
#  'cup',
#  'of',
#  'coffee',
#  'and',
#  'in',
#  'the',
#  'next',
#  'instant',
#  'drowned',
#  'in',
#  'it',
#  '.',
#  'Drowning',
#  'in',
#  'one',
#  'glass',
#  'of',
#  'whiskey',
#  ...]

# %%
new = []
for i in data2:
    new.append(i.lower())

# %%
new
# Out:
# ['a',
#  'somewhat',
#  'poor',
#  'but',
#  'honest',
#  'philosopher',
#  'searching',
#  'for',
#  'a',
#  'cosmic',
#  'law',
#  'carried',
#  'a',
#  'telescope',
#  'to',
#  'the',
#  'flat',
#  'rooftop',
#  'to',
#  'search',
#  'for',
#  'the',
#  'motion',
#  'of',
#  'the',
#  'universe',
#  '.',
#  'like',
#  'always',
#  ',',
#  'he',
#  'did',
#  'not',
#  'seem',
#  'to',
#  'discover',
#  'any',
#  'promise',
#  'of',
#  'a',
#  'star',
#  "'s",
#  'position',
#  '--only',
#  'any',
#  'number',
#  'of',
#  'meaningless',
#  'falling',
#  'stars',
#  ',',
#  'and',
#  'it',
#  'looked',
#  'like',
#  'he',
#  'would',
#  'discern',
#  'what',
#  'was',
#  'expected',
#  'so',
#  ',',
#  'out',
#  'of',
#  'tedium',
#  ',',
#  'it',
#  'was',
#  'no',
#  'wonder',
#  'that',
#  'he',
#  'innocently',
#  'turned',
#  'the',
#  'telescope',
#  'to',
#  'the',
#  'ground',
#  '.',
#  'he',
#  'saw',
#  'the',
#  'street',
#  'below',
#  'inverted',
#  'in',
#  'the',
#  'telescope',
#  ';',
#  'similarly',
#  'he',
#  'could',
#  'see',
#  'a',
#  'laborer',
#  'walking',
#  'upside',
#  'down',
#  '.',
#  'within',
#  'his',
#  'consciousness',
#  ',',
#  'those',
#  'inverted',
#  'images',
#  'were',
#  'returned',
#  'to',
#  'normal',
#  'relations',
#  'as',
#  'he',
#  'moved',
#  'the',
#  'lens',
#  'to',
#  'follow',
#  'the',
#  'worker',
#  "'s",
#  'movement',
#  '.',
#  'through',
#  'the',
#  'large',
#  'lens',
#  ',',
#  'he',
#  'could',
#  'see',
#  'through',
#  'the',
#  'worker',
#  "'s",
#  'small',
#  'head',
#  '.',
#  'this',
#  'was',
#  'because',
#  ',',
#  'after',
#  'returning',
#  'from',
#  'the',
#  'night',
#  'shift',
#  'at',
#  'the',
#  'factory',
#  ',',
#  'there',
#  'was',
#  'nothing',
#  'but',
#  'fatigue',
#  'in',
#  'his',
#  'head',
#  '.',
#  'however',
#  ',',
#  'the',
#  'patient',
#  'philosopher',
#  'would',
#  'not',
#  'turn',
#  'his',
#  'lens',
#  'away',
#  ';',
#  'furthermore',
#  ',',
#  'he',
#  'continued',
#  'to',
#  'pursue',
#  'the',
#  'worker',
#  '.',
#  'soon',
#  'that',
#  'patience',
#  'was',
#  'rewarded',
#  ':',
#  'suddenly',
#  'a',
#  'metamorphosis',
#  'overcame',
#  'the',
#  'worker',
#  '.',
#  'his',
#  'body',
#  'suddenly',
#  'became',
#  'an',
#  'opaque',
#  ',',
#  'meaningless',
#  'profile',
#  'while',
#  'he',
#  'crouched',
#  'in',
#  'slime',
#  ',',
#  'melting',
#  'from',
#  'his',
#  'leg',
#  ',',
#  'becoming',
#  'a',
#  'plump',
#  'mass',
#  'of',
#  'n1ucus',
#  ',',
#  'with',
#  'only',
#  'his',
#  'clothes',
#  ',',
#  'hat',
#  ',',
#  'and',
#  'shoes',
#  'left',
#  'behind',
#  '.',
#  'finally',
#  ',',
#  'the',
#  'completely',
#  'fluid',
#  'worker',
#  'spread',
#  'out',
#  'across',
#  'the',
#  'level',
#  'ground',
#  '.',
#  'the',
#  'liquefied',
#  'worker',
#  'quietly',
#  'began',
#  'to',
#  'flow',
#  'toward',
#  'tile',
#  'lower',
#  'ground',
#  '.',
#  'he',
#  'flowed',
#  'into',
#  'a',
#  'sunken',
#  'place',
#  'in',
#  'the',
#  'road',
#  '.',
#  'then',
#  'he',
#  'came',
#  'out',
#  '.',
#  'the',
#  'philosopher',
#  'was',
#  'so',
#  'frightened',
#  'that',
#  'he',
#  'almost',
#  'dropped',
#  'the',
#  'telescope',
#  'upon',
#  'seeing',
#  'the',
#  'motion',
#  'of',
#  'the',
#  'liquid',
#  'worker',
#  'going',
#  'against',
#  'hydrodynamic',
#  'law',
#  '.',
#  'flowing',
#  'more',
#  'and',
#  'nl0re',
#  'along',
#  'the',
#  'roadside',
#  ',',
#  'he',
#  'ran',
#  'into',
#  'a',
#  'wall',
#  ',',
#  'which',
#  'he',
#  'crawled',
#  'up',
#  'like',
#  'a',
#  'living',
#  'creature',
#  'grasping',
#  'on',
#  'its',
#  'film',
#  'of',
#  'slime',
#  '.',
#  'the',
#  'philosopher',
#  'let',
#  'go',
#  'of',
#  'the',
#  'telescope',
#  'and',
#  'breathed',
#  'a',
#  'heavy',
#  'sigh',
#  '.',
#  'the',
#  'next',
#  'day',
#  ',',
#  'the',
#  'philosopher',
#  'predicted',
#  'that',
#  'a',
#  'great',
#  'flood',
#  'was',
#  'facing',
#  'the',
#  'world',
#  '.',
#  'as',
#  'a',
#  'matter',
#  'of',
#  'fact',
#  ',',
#  'as',
#  'this',
#  'announcement',
#  'was',
#  'about',
#  'to',
#  'reach',
#  'society',
#  ',',
#  'laborers',
#  'and',
#  'the',
#  'poor',
#  'were',
#  'beginning',
#  'to',
#  'liquefy',
#  '.',
#  'this',
#  'collective',
#  'liquefaction',
#  'was',
#  'especially',
#  'remarkable',
#  '.',
#  'at',
#  'the',
#  'large',
#  'factories',
#  ',',
#  'the',
#  'operation',
#  'of',
#  'machinery',
#  'suddenly',
#  'came',
#  'to',
#  'a',
#  'standstill',
#  '.',
#  'all',
#  'at',
#  'once',
#  'the',
#  'mass',
#  'of',
#  'people',
#  'liquefied',
#  ',',
#  'forming',
#  'a',
#  'small',
#  'stream',
#  'and',
#  'started',
#  'to',
#  'flow',
#  'under',
#  'the',
#  'space',
#  'in',
#  'the',
#  'doors',
#  ',',
#  'climbing',
#  'up',
#  'the',
#  'walls',
#  'and',
#  'out',
#  'the',
#  'windows',
#  '.',
#  'the',
#  'system',
#  'was',
#  'upset',
#  ',',
#  "'finally",
#  'collapsing',
#  'after',
#  'the',
#  'workers',
#  'completely',
#  'liquified',
#  ',',
#  'for',
#  'no',
#  'one',
#  'in',
#  'the',
#  'disorder',
#  'within',
#  'the',
#  'factory',
#  'could',
#  'maintain',
#  'the',
#  'operation',
#  'of',
#  'the',
#  'machines',
#  '.',
#  'additionally',
#  ',',
#  'the',
#  'convicts',
#  'in',
#  'the',
#  'prisons',
#  'liquified',
#  'en',
#  'masse',
#  ',',
#  'plotting',
#  'an',
#  'escape',
#  ',',
#  'and',
#  'all',
#  'the',
#  'peasants',
#  'in',
#  'one',
#  'village',
#  'liquified',
#  ',',
#  'causing',
#  'a',
#  'small',
#  'flood',
#  '.',
#  'one',
#  'story',
#  'after',
#  'another',
#  'was',
#  'reported',
#  'in',
#  'the',
#  'newspapers',
#  '.',
#  'this',
#  'liquefaction',
#  'of',
#  'human',
#  'beings',
#  'was',
#  'progressing',
#  'fluidly',
#  ':',
#  'this',
#  'brought',
#  'about',
#  'confusion',
#  'on',
#  'various',
#  'faces',
#  '.',
#  'perfect',
#  'crimes',
#  'were',
#  'radically',
#  'increasing',
#  'from',
#  'the',
#  'liquid',
#  'criminals',
#  ',',
#  'disturbing',
#  'the',
#  'public',
#  'peace',
#  'and',
#  'order',
#  '.',
#  'at',
#  'the',
#  'police',
#  'station',
#  'physicists',
#  'were',
#  'meeting',
#  'in',
#  'secret',
#  'to',
#  'mobilizing',
#  ',',
#  'inquiring',
#  'into',
#  'the',
#  'nature',
#  'of',
#  'this',
#  'fluid',
#  '.',
#  'however',
#  ',',
#  'the',
#  'liquid',
#  'flowed',
#  'perfectly',
#  'in',
#  'defiance',
#  'of',
#  'scientific',
#  'law',
#  ',',
#  'causing',
#  'the',
#  'physicists',
#  'to',
#  'think',
#  'that',
#  'the',
#  'chaos',
#  'must',
#  'be',
#  'some',
#  'sort',
#  'of',
#  'trick',
#  '.',
#  'if',
#  'one',
#  'tried',
#  'to',
#  'touch',
#  'the',
#  'fluid',
#  ',',
#  'though',
#  'it',
#  'did',
#  'not',
#  'seem',
#  'even',
#  'a',
#  'little',
#  'different',
#  'from',
#  'water',
#  ',',
#  'it',
#  'would',
#  'display',
#  'a',
#  'mercury',
#  '-like',
#  'surface',
#  'tension',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'time',
#  '.',
#  'because',
#  'it',
#  'could',
#  'maintain',
#  'its',
#  'very',
#  'own',
#  'amoeba',
#  '-like',
#  'outline',
#  ',',
#  'it',
#  'could',
#  'do',
#  'more',
#  'than',
#  'just',
#  'climb',
#  'from',
#  'the',
#  'low',
#  'to',
#  'high',
#  'places',
#  ',',
#  'as',
#  'has',
#  'been',
#  'mentioned',
#  'before',
#  '.',
#  'the',
#  'liquefied',
#  'people',
#  ',',
#  'after',
#  'once',
#  'completely',
#  'softening',
#  'as',
#  'per',
#  'the',
#  'nature',
#  'of',
#  'this',
#  'fluid',
#  ',',
#  'continued',
#  'dividing',
#  'regardless',
#  'of',
#  'the',
#  'amount',
#  'of',
#  'any',
#  'stimulus',
#  'they',
#  'received',
#  '.',
#  'still',
#  ',',
#  'there',
#  'were',
#  'times',
#  'when',
#  'the',
#  'fluid',
#  'would',
#  'display',
#  'an',
#  'alcohol',
#  '-like',
#  'weak',
#  'surface',
#  'tension',
#  '.',
#  'at',
#  'that',
#  'time',
#  ',',
#  'it',
#  'displayed',
#  'an',
#  'abnormally',
#  'strong',
#  'osmotic',
#  'tendency',
#  'against',
#  'the',
#  'solids',
#  'it',
#  'was',
#  'sliding',
#  'over',
#  '.',
#  'that',
#  'is',
#  'to',
#  'say',
#  'that',
#  'even',
#  'against',
#  'a',
#  'homogenous',
#  'film',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'time',
#  ',',
#  'it',
#  'was',
#  'likely',
#  'to',
#  'vary',
#  'in',
#  'its',
#  'responses',
#  ',',
#  'having',
#  'quite',
#  'unreactive',
#  'chemical',
#  'properties',
#  '.',
#  'the',
#  'liquefied',
#  'people',
#  'could',
#  'also',
#  'freeze',
#  'and',
#  'evaporate',
#  '.',
#  'the',
#  'freezing',
#  'point',
#  'and',
#  'point',
#  'of',
#  'vaporization',
#  'were',
#  'diverse',
#  '.',
#  'thus',
#  ',',
#  'sleds',
#  'running',
#  'on',
#  'thick',
#  'ice',
#  'were',
#  'beginning',
#  'to',
#  'sink',
#  'one',
#  'by',
#  'one',
#  ',',
#  'or',
#  'suddenly',
#  'the',
#  'swift',
#  'lead',
#  'skater',
#  'in',
#  'a',
#  'race',
#  'would',
#  'vanish',
#  '.',
#  'also',
#  ',',
#  'in',
#  'midsummer',
#  'the',
#  'pools',
#  'rapidly',
#  'evaporated',
#  ',',
#  'and',
#  'young',
#  'women',
#  'swimming',
#  'were',
#  'occasionally',
#  'completely',
#  'encased',
#  'in',
#  'ice',
#  '.',
#  'the',
#  'liquid',
#  'people',
#  'were',
#  'clirnbing',
#  'the',
#  'mountains',
#  ',',
#  'getting',
#  'mixed',
#  'with',
#  'the',
#  'rivers',
#  ',',
#  'crossing',
#  'the',
#  'oceans',
#  ',',
#  'becoming',
#  'clouds',
#  'of',
#  'steam',
#  ',',
#  'and',
#  'becoming',
#  'rainfalls',
#  ',',
#  'spreading',
#  'out',
#  'throughout',
#  'a',
#  'world',
#  'completely',
#  'unprepared',
#  'for',
#  'such',
#  'an',
#  'occurrence',
#  '.',
#  'chemistry',
#  'experiments',
#  'fell',
#  'into',
#  'an',
#  'almost',
#  'impossible',
#  'state',
#  'of',
#  'affairs',
#  '.',
#  'the',
#  'boilers',
#  'of',
#  'steam',
#  'locomotives',
#  'did',
#  'not',
#  'withstand',
#  'the',
#  'aggressive',
#  'mingling',
#  'of',
#  'the',
#  'liquefied',
#  'people',
#  '.',
#  'no',
#  'matter',
#  'how',
#  'much',
#  'one',
#  'boiled',
#  ',',
#  'the',
#  'pressure',
#  'would',
#  'not',
#  'increase',
#  ';',
#  'then',
#  'the',
#  'boiler',
#  'would',
#  'expand',
#  'radically',
#  'and',
#  'explode',
#  '.',
#  'the',
#  'effect',
#  'the',
#  'fluid',
#  'had',
#  'upon',
#  'ichthyology',
#  'and',
#  'marine',
#  'botany',
#  'was',
#  'beyond',
#  'words',
#  '.',
#  'for',
#  'whatever',
#  'biological',
#  'reason',
#  ',',
#  'immeasurable',
#  'changes',
#  'and',
#  'extinctions',
#  'were',
#  'beginning',
#  '.',
#  'singing',
#  ',',
#  'writhing',
#  'apples',
#  ',',
#  'erupting',
#  'rice',
#  'plants',
#  'that',
#  'raised',
#  'a',
#  'sound',
#  'like',
#  'fireworks',
#  ',',
#  'and',
#  'other',
#  'new',
#  'botanical',
#  'varieties',
#  'were',
#  'discovered',
#  '.',
#  'particularly',
#  'serious',
#  'were',
#  'the',
#  'effects',
#  'on',
#  'those',
#  'people',
#  'still',
#  'not',
#  'liquified',
#  ',',
#  'most',
#  'of',
#  'whom',
#  'were',
#  'especially',
#  'wealthy',
#  'people',
#  '.',
#  'one',
#  'morning',
#  'a',
#  'factory',
#  'foreman',
#  'tried',
#  'to',
#  'take',
#  'a',
#  'sip',
#  'from',
#  'his',
#  'cup',
#  'of',
#  'coffee',
#  'and',
#  'in',
#  'the',
#  'next',
#  'instant',
#  'drowned',
#  'in',
#  'it',
#  '.',
#  'drowning',
#  'in',
#  'one',
#  'glass',
#  'of',
#  'whiskey',
#  ...]

# %%
def make_bigram(wordlist):
    bigram = {}
    key = wordlist[0]
    for word in wordlist[1:]:
        
        # keyがbigramに存在しない場合、
        # 辞書にkeyを追加
        
        if key not in bigram:
            bigram[key] = [word]
        else:
            bigram[key].append(word)
        
        # keyを更新
        key = word
        
    return bigram

# %%
make_bigram(new)
# Out:
# {'!': ['this'],
#  '!"': ['however'],
#  '"hey,': ['whose'],
#  '"when': ['i'],
#  "'finally": ['collapsing'],
#  "'flood": ['was'],
#  "'m": ['afraid'],
#  "'s": ['position', 'movement', 'small'],
#  "'t": ['think'],
#  ',': ['he',
#   'and',
#   'out',
#   'it',
#   'those',
#   'he',
#   'after',
#   'there',
#   'the',
#   'he',
#   'meaningless',
#   'melting',
#   'becoming',
#   'with',
#   'hat',
#   'and',
#   'the',
#   'he',
#   'which',
#   'the',
#   'as',
#   'laborers',
#   'the',
#   'forming',
#   'climbing',
#   "'finally",
#   'for',
#   'the',
#   'plotting',
#   'and',
#   'causing',
#   'disturbing',
#   'inquiring',
#   'the',
#   'causing',
#   'though',
#   'it',
#   'depending',
#   'it',
#   'as',
#   'after',
#   'continued',
#   'there',
#   'it',
#   'depending',
#   'it',
#   'having',
#   'sleds',
#   'or',
#   'in',
#   'and',
#   'getting',
#   'crossing',
#   'becoming',
#   'and',
#   'spreading',
#   'the',
#   'immeasurable',
#   'writhing',
#   'erupting',
#   'and',
#   'most',
#   'but',
#   'but',
#   'many',
#   'i',
#   'the',
#   'and',
#   'i',
#   'even',
#   'this',
#   'old',
#   'any',
#   'the',
#   'at',
#   'that',
#   'even',
#   'as',
#   'no',
#   'soon',
#   'they',
#   'despairing',
#   'while',
#   'neither',
#   'in',
#   'spirit',
#   'forced',
#   'still',
#   'even',
#   'knew',
#   'the',
#   'true',
#   'the',
#   'not',
#   'one',
#   'promising',
#   'full',
#   'it',
#   'the',
#   'and',
#   'buried',
#   'and',
#   'which',
#   'was',
#   'everyone',
#   'occasionally',
#   'there',
#   'noah',
#   'he',
#   'when',
#   'noah',
#   'bringing',
#   'immediately',
#   'get',
#   'thinking',
#   'the',
#   'in',
#   'the',
#   'floating',
#   'in',
#   'if',
#   'some'],
#  '--only': ['any'],
#  '-like': ['surface', 'outline', 'weak'],
#  '-scale': ['support'],
#  '-wide': ['distribution'],
#  '.': ['like',
#   'he',
#   'within',
#   'through',
#   'this',
#   'however',
#   'soon',
#   'his',
#   'finally',
#   'the',
#   'he',
#   'then',
#   'the',
#   'flowing',
#   'the',
#   'the',
#   'as',
#   'this',
#   'at',
#   'all',
#   'the',
#   'additionally',
#   'one',
#   'this',
#   'perfect',
#   'at',
#   'however',
#   'if',
#   'because',
#   'the',
#   'still',
#   'at',
#   'that',
#   'the',
#   'the',
#   'thus',
#   'also',
#   'the',
#   'chemistry',
#   'the',
#   'no',
#   'the',
#   'for',
#   'singing',
#   'particularly',
#   'one',
#   'drowning',
#   'it',
#   'when',
#   'high',
#   '"when',
#   'in',
#   'for',
#   'however',
#   'meanwhile',
#   'however',
#   'an',
#   'no',
#   'this',
#   'however',
#   'this',
#   'finally',
#   'nevertheless',
#   'but',
#   'any',
#   'against',
#   'at',
#   'they',
#   'in',
#   'thereupon',
#   'nevertheless',
#   'going',
#   'four',
#   'however',
#   'they',
#   'at',
#   'the',
#   'but',
#   'due',
#   'then',
#   'reorganization',
#   'unrest',
#   'due',
#   'in',
#   'this',
#   'because',
#   'thinking',
#   'presently',
#   'then',
#   'noah',
#   'there',
#   'so',
#   'to',
#   'so',
#   'the',
#   'thus',
#   'nevertheless',
#   'maybe'],
#  '."': ['in'],
#  ':': ['suddenly', 'this', 'this', 'this', 'any', 'as', '"hey,'],
#  ';': ['similarly', 'furthermore', 'then'],
#  '?': ['i'],
#  'a': ['somewhat',
#   'cosmic',
#   'telescope',
#   'star',
#   'laborer',
#   'metamorphosis',
#   'plump',
#   'sunken',
#   'wall',
#   'living',
#   'heavy',
#   'great',
#   'matter',
#   'standstill',
#   'small',
#   'small',
#   'little',
#   'mercury',
#   'homogenous',
#   'race',
#   'world',
#   'sound',
#   'factory',
#   'sip',
#   'harsh',
#   'great',
#   'fact',
#   'fact',
#   'proclamation',
#   'great',
#   'consequence',
#   'geometric',
#   'dry',
#   'breath',
#   'loud',
#   'hasty'],
#  'able': ['to'],
#  'abnormally': ['strong'],
#  'about': ['to', 'confusion', 'the', 'missing', 'the', 'vaporizing'],
#  'abruptly': ['flooded'],
#  'acknowledged': ['the'],
#  'acknowledging': ['this'],
#  'across': ['the'],
#  'actually': ['tried'],
#  'additionally': [','],
#  'adrift': [','],
#  'advent': ['of'],
#  'affairs': ['.'],
#  'afraid': ['."'],
#  'after': ['returning', 'the', 'another', 'once', 'another'],
#  'against': ['hydrodynamic', 'the', 'a', 'these', 'quantum', 'the'],
#  'aggressive': ['mingling'],
#  'alcohol': ['-like'],
#  'all': ['at', 'the', 'the', 'of', 'the'],
#  'almost': ['dropped',
#   'impossible',
#   'unbelievable',
#   'everyone',
#   'no',
#   'impossible'],
#  'along': ['the', 'his'],
#  'already': ['on'],
#  'also': ['freeze', ',', 'a'],
#  'always': [','],
#  'am': ['sure', 'noah'],
#  'amid': ['myriad'],
#  'amoeba': ['-like'],
#  'amount': ['of'],
#  'an': ['opaque',
#   'escape',
#   'alcohol',
#   'abnormally',
#   'occurrence',
#   'almost',
#   'example',
#   'unseen',
#   'increase',
#   'ark'],
#  'and': ['it',
#   'shoes',
#   'nl0re',
#   'breathed',
#   'the',
#   'started',
#   'out',
#   'all',
#   'order',
#   'evaporate',
#   'point',
#   'young',
#   'becoming',
#   'explode',
#   'marine',
#   'extinctions',
#   'other',
#   'in',
#   'harmful',
#   'i',
#   'suffering',
#   'convulse',
#   'repeatedly',
#   'total',
#   'geology',
#   'towns',
#   'hills',
#   'wealthy',
#   'body',
#   'duty',
#   'rulers',
#   'exceeding',
#   'information',
#   'its',
#   'scientists',
#   'the',
#   'distress',
#   'uttering',
#   'his',
#   'domestic',
#   'all',
#   'street',
#   'towns'],
#  'animals': ['.'],
#  'announced': ['by'],
#  'announcement': ['was'],
#  'annual': ['average', 'seasonal'],
#  'another': ['was', ','],
#  'any': ['promise', 'number', 'stimulus', 'effect', 'number', 'number'],
#  'apples': [','],
#  'approval': [','],
#  'areas': [','],
#  'ark': ['without', ',', '.', 'was', 'was'],
#  'around': ['to'],
#  'as': ['he', 'a', 'this', 'has', 'per', 'the', 'usual', 'it', 'able'],
#  'at': ['the',
#   'the',
#   'once',
#   'the',
#   'that',
#   'once',
#   'the',
#   'first',
#   'last',
#   'this',
#   'the'],
#  'atomic': ['energy', 'energy'],
#  'average': ['for'],
#  'away': [';', ','],
#  'be': ['some', 'mobilized'],
#  'became': ['an'],
#  'because': [',', 'it', 'the', 'of'],
#  'becoming': ['a', 'clouds', 'rainfalls'],
#  'been': ['mentioned'],
#  'before': ['.', 'the'],
#  'began': ['to', 'to'],
#  'beginning': ['to', 'to', '.', 'was', 'to'],
#  'behind': ['.'],
#  'beings': ['was'],
#  'below': ['inverted'],
#  'better': ['steep'],
#  'beyond': ['words'],
#  'biological': ['reason'],
#  'boarded': ['the'],
#  'boat': ['do'],
#  'body': ['suddenly', 'must'],
#  'boiled': [','],
#  'boiler': ['would'],
#  'boilers': ['of'],
#  'botanical': ['varieties'],
#  'botany': ['was'],
#  'bottom': ['.', 'of', ','],
#  'bowers': ['and'],
#  'breath': ['.'],
#  'breathed': ['a'],
#  'bringing': ['along'],
#  'brought': ['about'],
#  'build': ['a'],
#  'building': ['an'],
#  'buried': ['in'],
#  'but': ['honest', 'fatigue', 'even', 'it', 'the', 'when'],
#  'by': ['one', 'an', 'day', 'the', 'the'],
#  'calm': ['person', 'sea'],
#  'came': ['out', 'to', 'around'],
#  'carried': ['a'],
#  'cause': ['.', ':'],
#  'causing': ['a', 'the'],
#  'change': ['in'],
#  'changes': ['and'],
#  'chaos': ['must'],
#  'chemical': ['properties'],
#  'chemistry': ['experiments'],
#  'citizens': ['.'],
#  'clearly': ['hydrophobia', 'climb'],
#  'climate': ['and'],
#  'climb': ['from', 'walls'],
#  'climbing': ['up'],
#  'clirnbing': ['the'],
#  'clothes': [','],
#  'clouds': ['of'],
#  'coffee': ['and'],
#  'collapsing': ['after'],
#  'collective': ['liquefaction'],
#  'commence': ['production'],
#  'completely': ['fluid', 'liquified', 'softening', 'encased', 'unprepared'],
#  'comprehend': ['his'],
#  'conducted': ['that'],
#  'confusion': ['on'],
#  'consciousness': [','],
#  'consequence': ['of'],
#  'construction': ['because'],
#  'continued': ['to', 'dividing'],
#  'contradiction': ['stirred'],
#  'contradictory': ['nature'],
#  'convicts': ['in'],
#  'convulse': ['upon'],
#  'corners': ['of'],
#  'cosmic': ['law'],
#  'could': ['see',
#   'see',
#   'maintain',
#   'maintain',
#   'do',
#   'also',
#   'better',
#   'comprehend',
#   'have'],
#  'covered': ['by'],
#  'crawl': ['up'],
#  'crawled': ['up'],
#  'creature': ['grasping'],
#  'creatures': ['drowned'],
#  'crimes': ['were'],
#  'criminals': [','],
#  'crossing': ['the'],
#  'crouched': ['in'],
#  'crystallize': ['.'],
#  'cunning': ['noah'],
#  'cup': ['of', '.'],
#  'day': [',', 'by', ':'],
#  'defiance': ['of'],
#  'dehydration': [','],
#  'denied': ['them'],
#  'depending': ['on', 'on'],
#  'descriptions': ['and'],
#  'despairing': ['the'],
#  'destroyed': ['one'],
#  'destruction': ['by'],
#  'developed': ['the'],
#  'did': ['not', 'not', 'not', 'indeed', 'not'],
#  'different': ['from'],
#  'difficulties': ['.'],
#  'dike': ['had'],
#  'disasters': ['everywhere'],
#  'discern': ['what'],
#  'discover': ['any'],
#  'discovered': ['.'],
#  'disorder': ['within'],
#  'display': ['a', 'an'],
#  'displayed': ['an'],
#  'distress': ['overshadowed'],
#  'distribution': ['and'],
#  'disturbing': ['the'],
#  'diverse': ['.'],
#  'dividing': ['regardless'],
#  'do': ['more', 'you'],
#  'domestic': ['animals'],
#  'don': ["'t"],
#  'doors': [','],
#  'down': ['.'],
#  'drink': ['water'],
#  'driven': ['away'],
#  'drop': ['of'],
#  'dropped': ['the'],
#  'drops': ['turned'],
#  'drowned': ['in', '.'],
#  'drowning': ['in', 'in'],
#  'dry': ['sound'],
#  'due': ['to', 'to'],
#  'duty': ['towards'],
#  'ecstasy': ['.'],
#  'edge': ['of'],
#  'effect': ['the', 'of', 'whatsoever'],
#  'effects': ['on'],
#  'en': ['masse'],
#  'encased': ['in'],
#  'end': ['.', 'of', 'naturally'],
#  'energy': ['.', 'plant'],
#  'enjoying': ['himself'],
#  'entrusted': ['in'],
#  'eradicated': ['.'],
#  'erupting': ['rice'],
#  'escape': [','],
#  'especially': ['remarkable', 'wealthy'],
#  'estimated': ['as'],
#  'evacuate': ['from'],
#  'evacuation': ['was'],
#  'evaporate': ['.'],
#  'evaporated': [','],
#  'even': ['a', 'against', 'an', 'if', 'the', 'the', 'the'],
#  'everyone': [',', 'was'],
#  'everywhere': [','],
#  'example': [',', 'of', ','],
#  'exceeding': ['newtonian'],
#  'expand': ['radically'],
#  'expanding': ['day'],
#  'expected': ['so'],
#  'experiences': ['before'],
#  'experiments': ['fell'],
#  'explode': ['.'],
#  'extinctions': ['were'],
#  'extolling': ['the'],
#  'eye': ['drops'],
#  'faces': ['.'],
#  'facing': ['the'],
#  'fact': [',', '.', '.'],
#  'factories': [',', 'were'],
#  'factory': [',', 'could', 'foreman'],
#  'facts': ['about'],
#  'fainting': ['at'],
#  'fall': ['simply'],
#  'falling': ['stars'],
#  'family': [',', 'and'],
#  'fatigue': ['in'],
#  'fell': ['into'],
#  'fields': ['and'],
#  'filled': ['with', 'with'],
#  'film': ['of', ','],
#  'finally': [',', ','],
#  'fireworks': [','],
#  'first': ['the'],
#  'flat': ['rooftop'],
#  'floating': ['at'],
#  'flood': ['was',
#   '.',
#   'was',
#   'was',
#   '.',
#   ',',
#   ',',
#   'and',
#   ',',
#   'neared',
#   'humanity'],
#  'flooded': ['.'],
#  'flow': ['toward', 'under'],
#  'flowed': ['into', 'perfectly'],
#  'flowing': ['more'],
#  'fluid': ['worker',
#   '.',
#   ',',
#   ',',
#   'would',
#   'had',
#   'mechanics',
#   '.',
#   'could',
#   ','],
#  'fluidly': [':'],
#  'follow': ['the'],
#  'for': ['a',
#   'the',
#   'no',
#   'such',
#   'whatever',
#   'example',
#   'some',
#   'rai',
#   'the'],
#  'forced': ['labor'],
#  'foreman': ['tried'],
#  'form': [','],
#  'forming': ['a'],
#  'four': ['pages'],
#  'freeze': ['and'],
#  'freezing': ['point'],
#  'frightened': ['that'],
#  'from': ['the',
#   'his',
#   'the',
#   'water',
#   'the',
#   'his',
#   'one',
#   'the',
#   'the',
#   'destruction'],
#  'full': ['-scale'],
#  'fundamental': ['atomic'],
#  'furthermore': [','],
#  'futile': [','],
#  'future': ['.', 'of'],
#  'gasping': ['and'],
#  'gave': ['its'],
#  'general': ['social'],
#  'generous': [','],
#  'geology': ['was'],
#  'geometric': ['progression'],
#  'get': ['sick', 'the', 'off'],
#  'getting': ['mixed'],
#  'glass': ['of'],
#  'go': ['of'],
#  'going': ['against', 'against'],
#  'government': ['officials', 'immediately'],
#  'grasping': ['on'],
#  'great': ['flood', 'flood', 'levee', 'flood'],
#  'ground': ['.', '.', '.'],
#  'had': ['upon', 'almost'],
#  'hands': ['and'],
#  'happen': ['.'],
#  'hard': ['in'],
#  'harmful': [','],
#  'harsh': ['example'],
#  'has': ['been'],
#  'hastening': ['to'],
#  'hasty': ['miscalculation'],
#  'hat': [','],
#  'have': ['tried'],
#  'having': ['quite'],
#  'he': ['did',
#   'would',
#   'innocently',
#   'saw',
#   'could',
#   'moved',
#   'could',
#   'continued',
#   'crouched',
#   'flowed',
#   'came',
#   'almost',
#   'ran',
#   'crawled',
#   'could'],
#  'head': ['.', '.'],
#  'heart': ['within'],
#  'heavy': ['sigh'],
#  'high': ['places', 'government'],
#  'hills': ['were'],
#  'himself': ['.', 'in'],
#  'his': ['consciousness',
#   'head',
#   'lens',
#   'body',
#   'leg',
#   'clothes',
#   'cup',
#   'experiences',
#   'presence',
#   'hands',
#   'family',
#   'home',
#   'family',
#   'words'],
#  'home': [','],
#  'homogenous': ['film'],
#  'honest': ['philosopher'],
#  'how': ['much'],
#  'however': [',', ',', ',', ',', ',', ',', ','],
#  'human': ['beings'],
#  'humanity': ['from', 'was', 'was'],
#  'hydrodynamic': ['law'],
#  'hydrodynamics': ['.'],
#  'hydrophobia': ['to', '.'],
#  'i': ['drink', 'don', 'look', 'am', "'m", 'am'],
#  'ice': ['were', '.'],
#  'ichthyology': ['and'],
#  'if': ['one', 'i', 'one', 'one'],
#  'illness': ['and'],
#  'illustration': [','],
#  'images': ['were'],
#  'immeasurable': ['changes'],
#  'immediately': ['gave', 'the'],
#  'impossible': ['state', 'amid'],
#  'in': ['the',
#   'his',
#   'slime',
#   'the',
#   'the',
#   'the',
#   'the',
#   'one',
#   'the',
#   'secret',
#   'defiance',
#   'its',
#   'a',
#   'midsummer',
#   'ice',
#   'the',
#   'it',
#   'one',
#   'one',
#   'the',
#   'short',
#   'its',
#   'illness',
#   'illustration',
#   'the',
#   'all',
#   'the',
#   'tone',
#   'order',
#   'hastening',
#   'order',
#   'extolling',
#   'a',
#   'time',
#   'the',
#   'all',
#   'steadily',
#   'his',
#   'religious',
#   'a',
#   'the',
#   'this'],
#  'increase': [';', 'in'],
#  'increasing': ['from'],
#  'indeed': ['happen'],
#  'indigestible': ['and'],
#  'information': ['was', 'about'],
#  'ingesting': ['it'],
#  'inhuman': ['fluid'],
#  'innocently': ['turned'],
#  'inquiring': ['into'],
#  'instant': ['drowned'],
#  'into': ['a', 'a', 'the', 'an', 'fluid', 'mummies', 'the'],
#  'inverted': ['in', 'images'],
#  'is': ['to',
#   'a',
#   'almost',
#   'water',
#   'quite',
#   'lower',
#   '?',
#   'my',
#   'no',
#   'the'],
#  'issued': ['a'],
#  'it': ['looked',
#   'was',
#   'did',
#   'would',
#   'could',
#   'could',
#   'displayed',
#   'was',
#   'was',
#   '.',
#   'is',
#   'did',
#   'is',
#   'would',
#   'was',
#   'was',
#   'was',
#   '.'],
#  'its': ['film',
#   'very',
#   'responses',
#   'liquid',
#   'construction',
#   'root',
#   'cause',
#   'approval'],
#  'joined': ['together'],
#  'just': ['climb'],
#  'kept': ['silent'],
#  'kings': ['and'],
#  'knew': ['that', 'that'],
#  'labor': ['was'],
#  'laborer': ['walking'],
#  'laborers': ['and', 'were'],
#  'land': ['from'],
#  'large': ['lens', 'factories'],
#  'last': ['the'],
#  'law': ['carried', '.', ','],
#  'lead': ['skater'],
#  'leaders': ['acknowledged'],
#  'left': ['behind'],
#  'leg': [','],
#  'lens': ['to', ',', 'away'],
#  'let': ['go'],
#  'letter': ['.'],
#  'levee': ['.'],
#  'level': ['ground'],
#  'like': ['always', 'he', 'a', 'fireworks', 'other'],
#  'likely': ['to'],
#  'limits': ['of'],
#  'liquefaction': ['was', 'of'],
#  'liquefied': ['worker',
#   ',',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people'],
#  'liquefy': ['.'],
#  'liquefying': ['.', 'turned'],
#  'liquid': ['worker',
#   'criminals',
#   'flowed',
#   'people',
#   'state',
#   'people',
#   'that',
#   'and'],
#  'liquified': [',', 'en', ',', ','],
#  'little': ['different'],
#  'living': ['creature', 'creatures'],
#  'locomotives': ['did'],
#  'look': ['in', 'into'],
#  'looked': ['like'],
#  'losing': ['his'],
#  'loud': ['voice'],
#  'low': ['to'],
#  'lower': ['ground', '.'],
#  'machinery': ['suddenly'],
#  'machines': ['.'],
#  'maintain': ['the', 'its'],
#  'manufacturing': ['factories'],
#  'many': ['of'],
#  'marine': ['botany'],
#  'mass': ['of', 'of'],
#  'masse': [','],
#  'matter': ['of', 'how'],
#  'maybe': ['this'],
#  'meaningless': ['falling', 'profile'],
#  'meanwhile': ['from'],
#  'mechanics': ['and', ','],
#  'meeting': ['in'],
#  'melting': ['from'],
#  'mentioned': ['before'],
#  'mercury': ['-like'],
#  'mercy': ['of'],
#  'merely': ['a'],
#  'metamorphosis': ['overcame'],
#  'midsummer': ['the'],
#  'millions': ['of'],
#  'mind': ['.'],
#  'mingling': ['of'],
#  'miscalculation': ['.'],
#  'missing': ['citizens'],
#  'mistaking': ['it'],
#  'mixed': ['with'],
#  'mobilized': ['in'],
#  'mobilizing': [','],
#  'moment': [','],
#  'more': ['and', 'than', 'than'],
#  'morning': ['a'],
#  'most': ['of'],
#  'motion': ['of', 'of'],
#  'mountainous': ['areas'],
#  'mountains': [','],
#  'moved': ['the'],
#  'movement': ['.'],
#  'much': ['one'],
#  'mummies': [','],
#  'must': ['be', 'be'],
#  'my': ['ark'],
#  'myriad': ['difficulties'],
#  'n1ucus': [','],
#  'naked': ['truth'],
#  'natural': ['disasters'],
#  'naturally': [','],
#  'nature': ['of', 'of', 'of'],
#  'neared': ['his'],
#  'needed': [','],
#  'neither': ['was'],
#  'never': ['touched'],
#  'nevertheless': [',', ',', ','],
#  'new': ['botanical'],
#  'newspapers': ['.', 'for', 'came', 'joined', 'were', 'conducted'],
#  'newtonian': ['fluid'],
#  'next': ['day', 'instant', 'moment'],
#  'nfall': ['is'],
#  'night': ['shift'],
#  'nl0re': ['along'],
#  'no': ['wonder', 'one', 'matter', 'change', 'more', 'effect', 'mistaking'],
#  'noah': ['.', 'was', 'boarded', 'scolded', '!'],
#  'normal': ['relations'],
#  'not': ['seem',
#   'turn',
#   'seem',
#   'withstand',
#   'increase',
#   'liquified',
#   'get',
#   'reported',
#   'its',
#   'in'],
#  'noted': ['.'],
#  'nothing': ['but'],
#  'number': ['of', 'of', 'of'],
#  'occasionally': ['completely', 'gasping'],
#  'occurrence': ['.'],
#  'oceans': [','],
#  'of': ['the',
#   'a',
#   'meaningless',
#   'tedium',
#   'n1ucus',
#   'the',
#   'slime',
#   'the',
#   'fact',
#   'machinery',
#   'people',
#   'the',
#   'human',
#   'this',
#   'scientific',
#   'trick',
#   'this',
#   'the',
#   'any',
#   'vaporization',
#   'steam',
#   'affairs',
#   'steam',
#   'the',
#   'whom',
#   'coffee',
#   'whiskey',
#   'drowning',
#   'eye',
#   'the',
#   'hydrophobia',
#   'water',
#   'rabies',
#   'the',
#   'a',
#   'water',
#   'annual',
#   'the',
#   'beginning',
#   'villages',
#   'open',
#   'the',
#   'workers',
#   'and',
#   'the',
#   'the',
#   'the',
#   'liquefying',
#   'the',
#   'that',
#   'his',
#   'mind',
#   'humanity',
#   'the',
#   'the',
#   'the'],
#  'off': ['!"'],
#  'officials': ['were'],
#  'old': ['women'],
#  'on': ['its',
#   'various',
#   'the',
#   'the',
#   'thick',
#   'those',
#   'the',
#   'its',
#   'the',
#   'the',
#   'the'],
#  'once': ['the', 'completely', ','],
#  'one': ['in',
#   'village',
#   'story',
#   'tried',
#   'by',
#   ',',
#   'boiled',
#   'morning',
#   'glass',
#   'drop',
#   'did',
#   'end',
#   'scientist',
#   'after',
#   'calm',
#   'could'],
#  'only': ['his', 'one', 'problem'],
#  'opaque': [','],
#  'open': ['fields'],
#  'operation': ['of', 'of'],
#  'optimistic': ['in'],
#  'optimistically': ['cunning'],
#  'or': ['suddenly'],
#  'order': ['.', 'to', 'to'],
#  'osmotic': ['tendency'],
#  'other': ['new', ',', 'natural', 'side'],
#  'out': ['of', 'across', '.', 'the', 'throughout', 'about', 'in'],
#  'outline': [','],
#  'outside': ['salvation'],
#  'over': ['.'],
#  'overcame': ['the'],
#  'overshadowed': ['the'],
#  'own': ['amoeba'],
#  'owners': ['and'],
#  'pages': ['of'],
#  'particularly': ['serious'],
#  'patience': ['was'],
#  'patient': ['philosopher'],
#  'peace': ['and'],
#  'peasants': ['in'],
#  'people': ['liquefied',
#   ',',
#   'could',
#   'were',
#   '.',
#   'still',
#   '.',
#   'developed',
#   'while',
#   'were',
#   'who',
#   'against',
#   'spreading',
#   'tried',
#   '.'],
#  'per': ['the'],
#  'perfect': ['crimes'],
#  'perfectly': ['in'],
#  'pern1eated': ['the'],
#  'person': ['enjoying'],
#  'philosopher': ['searching', 'would', 'was', 'let', 'predicted'],
#  'physicists': ['were', 'to'],
#  'place': ['in'],
#  'places': [','],
#  'plant': [','],
#  'plants': ['that'],
#  'plateaus': ['to'],
#  'plotting': ['an'],
#  'plump': ['mass'],
#  'point': ['and', 'of'],
#  'police': ['station'],
#  'pools': ['rapidly'],
#  'poor': ['but', 'were'],
#  'position': ['--only'],
#  'predicted': ['that'],
#  'presence': ['of'],
#  'presently': [','],
#  'pressure': ['would'],
#  'previously': ['calm'],
#  'printed': ['these'],
#  'prisons': ['liquified'],
#  'problem': ['was'],
#  'proclamation': ['that', '.', 'was'],
#  'production': [','],
#  'profile': ['while'],
#  'progressing': ['fluidly'],
#  'progression': [','],
#  'promise': ['of'],
#  'promising': ['generous'],
#  'properties': ['.'],
#  'property': ['owners'],
#  'public': ['peace'],
#  'pursue': ['the'],
#  'quantum': ['mechanics'],
#  'quietly': ['began'],
#  'quite': ['unreactive', 'indigestible'],
#  'rabies': ['vaccinations'],
#  'race': ['would'],
#  'radically': ['increasing', 'and'],
#  'rai': ['nfall'],
#  'rainfalls': [','],
#  'raised': ['a'],
#  'ran': ['into'],
#  'rapidly': ['evaporated'],
#  'reach': ['society'],
#  'reason': [',', 'printed'],
#  'received': ['.'],
#  'regardless': ['of'],
#  'reinforcements': ['for'],
#  'relations': ['as'],
#  'religious': ['ecstasy'],
#  'remarkable': ['.'],
#  'reorganization': ['was'],
#  'repeated': ['.'],
#  'repeatedly': ['denied'],
#  'reported': ['in', '.', 'to'],
#  'reporting': ['the'],
#  'reports': ['and'],
#  'responses': [','],
#  'result': ['in'],
#  'returned': ['to'],
#  'returning': ['from'],
#  'revealed': [','],
#  'rewarded': [':'],
#  'rice': ['plants'],
#  'righteousness': ['of'],
#  'rivers': [',', 'was'],
#  'road': ['.'],
#  'roadside': [','],
#  'rooftop': ['to'],
#  'root': ['cause'],
#  'rounded': ['up'],
#  'rulers': ['themselves'],
#  'running': ['on'],
#  'salvation': ['.'],
#  'save': ['humanity'],
#  'saw': ['the'],
#  'say': ['that'],
#  'scientific': ['law'],
#  'scientist': ['spoke'],
#  'scientists': ['already'],
#  'scolded': ['in'],
#  'sea': ['bottom', '.', 'bottom'],
#  'search': ['for'],
#  'searching': ['for'],
#  'seasonal': ['variation'],
#  'second': ['flood'],
#  'secret': ['to'],
#  'see': ['a', 'through'],
#  'seeing': ['the'],
#  'seem': ['to', 'even'],
#  'seen': ['as'],
#  'serious': ['were'],
#  'shift': ['at'],
#  'shining': ['substance'],
#  'ship': ['.'],
#  'shoes': ['left'],
#  'short': [','],
#  'sick': ['and'],
#  'side': ['were'],
#  'sigh': ['.'],
#  'sight': ['of'],
#  'silent': ['about'],
#  'similarly': ['he'],
#  'simply': ['within'],
#  'singing': [','],
#  'sink': ['one'],
#  'sinking': ['to'],
#  'sip': ['from'],
#  'situation': ['.'],
#  'skater': ['in'],
#  'sleds': ['running'],
#  'sliding': ['over'],
#  'slime': [',', '.'],
#  'small': ['head', 'stream', 'flood'],
#  'so': [',', 'frightened', ',', ','],
#  'social': ['unrest'],
#  'society': [','],
#  'softening': ['as'],
#  'solids': ['it'],
#  'some': ['sort', 'reason', 'shining'],
#  'somewhat': ['poor'],
#  'soon': ['that', 'to'],
#  'sort': ['of'],
#  'sound': ['like', 'whenever'],
#  'space': ['in'],
#  'spirit': ['and'],
#  'spoke': ['out'],
#  'spread': ['out'],
#  'spreading': ['out', 'out'],
#  'standpoints': ['of'],
#  'standstill': ['.'],
#  'star': ["'s"],
#  'stars': [','],
#  'start': [','],
#  'started': ['to'],
#  'state': ['of', 'is'],
#  'station': ['physicists'],
#  'steadily': ['liquefying', 'building'],
#  'steam': [',', 'locomotives'],
#  'steep': ['himself'],
#  'still': [',', 'not', 'almost'],
#  'stimulus': ['they'],
#  'stirred': ['up'],
#  'story': ['after'],
#  'stream': ['and'],
#  'street': ['below', 'corners'],
#  'strong': ['osmotic'],
#  'substance': ['in', 'began'],
#  'such': ['an'],
#  'suddenly': ['a', 'became', 'came', 'the'],
#  'suffering': ['at'],
#  'sunken': ['place'],
#  'superfluous': ['.'],
#  'supersaturated': ['liquefied'],
#  'support': ['.'],
#  'sure': ['that'],
#  'surface': ['tension', 'tension'],
#  'swallowing': [','],
#  'swift': ['lead'],
#  'swimming': ['were'],
#  'symptoms': ['of'],
#  'system': ['was'],
#  'take': ['a'],
#  'tedium': [','],
#  'telescope': ['to', 'to', ';', 'upon', 'and'],
#  'temporary': [','],
#  'tendency': ['against'],
#  'tension': [',', '.'],
#  'than': ['just', 'temporary'],
#  'that': ['he',
#   'patience',
#   'he',
#   'a',
#   'the',
#   'time',
#   'is',
#   'even',
#   'raised',
#   'it',
#   'ingesting',
#   'the',
#   'this',
#   ',',
#   'the',
#   'this',
#   'pern1eated',
#   'this',
#   'the',
#   ',',
#   'the',
#   'the'],
#  'the': ['flat',
#   'motion',
#   'universe',
#   'telescope',
#   'ground',
#   'street',
#   'telescope',
#   'lens',
#   'worker',
#   'large',
#   'worker',
#   'night',
#   'factory',
#   'patient',
#   'worker',
#   'worker',
#   'completely',
#   'level',
#   'liquefied',
#   'road',
#   'philosopher',
#   'telescope',
#   'motion',
#   'liquid',
#   'roadside',
#   'philosopher',
#   'telescope',
#   'next',
#   'philosopher',
#   'world',
#   'poor',
#   'large',
#   'operation',
#   'mass',
#   'space',
#   'doors',
#   'walls',
#   'windows',
#   'system',
#   'workers',
#   'disorder',
#   'factory',
#   'operation',
#   'machines',
#   'convicts',
#   'prisons',
#   'peasants',
#   'newspapers',
#   'liquid',
#   'public',
#   'police',
#   'nature',
#   'liquid',
#   'physicists',
#   'chaos',
#   'fluid',
#   'time',
#   'low',
#   'liquefied',
#   'nature',
#   'amount',
#   'fluid',
#   'solids',
#   'time',
#   'liquefied',
#   'freezing',
#   'swift',
#   'pools',
#   'liquid',
#   'mountains',
#   'rivers',
#   'oceans',
#   'boilers',
#   'aggressive',
#   'liquefied',
#   'pressure',
#   'boiler',
#   'effect',
#   'fluid',
#   'effects',
#   'next',
#   'wealthy',
#   'symptoms',
#   'letter',
#   'cup',
#   'substance',
#   'sight',
#   'end',
#   'world',
#   'other',
#   'advent',
#   'newspapers',
#   'world',
#   'volume',
#   'rivers',
#   'limits',
#   'land',
#   'standpoints',
#   'climate',
#   'flood',
#   'verge',
#   'newspapers',
#   'facts',
#   'flood',
#   "'flood",
#   'sea',
#   'liquefied',
#   'plateaus',
#   'mountainous',
#   'future',
#   'leaders',
#   'urgency',
#   'situation',
#   'flood',
#   'millions',
#   'newspapers',
#   'righteousness',
#   'proclamation',
#   'kings',
#   'proclamation',
#   'liquid',
#   'dike',
#   'workers',
#   'other',
#   'newspapers',
#   'newspapers',
#   'flood',
#   'contradictory',
#   'flood',
#   'liquid',
#   'world',
#   'government',
#   'liquefied',
#   'reinforcements',
#   'laborers',
#   'verge',
#   'bottom',
#   'sea',
#   'naked',
#   'fundamental',
#   'world',
#   'dehydration',
#   'optimistically',
#   'great',
#   'future',
#   'flood',
#   'ark',
#   'liquefied',
#   'edge',
#   'ship',
#   'inhuman',
#   'fluid',
#   'only',
#   'next',
#   'ark',
#   'living',
#   'uninhabited',
#   'mercy',
#   'wind',
#   'bowers',
#   'villages',
#   'previously',
#   'unseen',
#   'supersaturated'],
#  'them': [':'],
#  'themselves': [','],
#  'then': ['he', 'the', 'manufacturing', ','],
#  'there': ['was', 'were', 'outside', 'was', 'is'],
#  'thereupon': ['even'],
#  'these': ['reports', 'liquefied'],
#  'they': ['received',
#   'were',
#   'repeated',
#   'knew',
#   'issued',
#   'kept',
#   'actually',
#   'took'],
#  'thick': ['ice'],
#  'think': ['that', 'that', 'this'],
#  'thinking': ['that', 'that'],
#  'this': ['was',
#   'announcement',
#   'collective',
#   'liquefaction',
#   'brought',
#   'fluid',
#   'fluid',
#   'information',
#   '.',
#   'was',
#   'year',
#   'was',
#   'contradiction',
#   'was',
#   'evacuation',
#   'was',
#   'time',
#   'was',
#   'was',
#   'is',
#   'is',
#   'second',
#   'is'],
#  'those': ['inverted', 'people'],
#  'though': ['it'],
#  'through': ['the', 'the'],
#  'throughout': ['a'],
#  'thus': [',', ','],
#  'tile': ['lower'],
#  'time': ['.', ',', ',', ',', ','],
#  'times': ['when'],
#  'to': ['the',
#   'search',
#   'discover',
#   'the',
#   'normal',
#   'follow',
#   'pursue',
#   'flow',
#   'reach',
#   'liquefy',
#   'a',
#   'flow',
#   'mobilizing',
#   'think',
#   'touch',
#   'high',
#   'say',
#   'vary',
#   'sink',
#   'take',
#   'the',
#   'the',
#   'fall',
#   'reporting',
#   'end',
#   'the',
#   'evacuate',
#   'the',
#   'save',
#   'build',
#   'get',
#   'form',
#   'start',
#   'the',
#   'commence',
#   'the',
#   'crawl',
#   'the',
#   'look',
#   'crystallize'],
#  'together': ['in'],
#  'tone': [':'],
#  'took': ['a'],
#  'total': ['annual'],
#  'touch': ['the'],
#  'touched': ['upon'],
#  'toward': ['tile'],
#  'towards': ['the'],
#  'towns': ['were', 'on'],
#  'trick': ['.'],
#  'tried': ['to', 'to', 'to', 'to', 'to'],
#  'true': ['to'],
#  'truth': ['was'],
#  'turn': ['his'],
#  'turned': ['the', 'up', 'into'],
#  'turning': ['into'],
#  'unbelievable': [','],
#  'under': ['the'],
#  'understood': ['that'],
#  'uninhabited': ['ark'],
#  'universe': ['.'],
#  'unprepared': ['for'],
#  'unreactive': ['chemical'],
#  'unrest': ['.', 'and'],
#  'unseen': ['voice', 'heart'],
#  'up': ['like', 'the', '.', 'general', '.', 'the'],
#  'upon': ['seeing', 'ichthyology', 'swallowing', '.'],
#  'upset': [','],
#  'upside': ['down'],
#  'urgency': ['of'],
#  'usual': ['they'],
#  'uttering': ['a'],
#  'vaccinations': ['was'],
#  'vanish': ['.'],
#  'vaporization': ['were'],
#  'vaporizing': ['the'],
#  'variation': ['.'],
#  'varieties': ['were'],
#  'various': ['faces'],
#  'vary': ['in'],
#  'verge': ['of', 'of'],
#  'very': ['own'],
#  'village': ['liquified'],
#  'villages': ['and', 'and'],
#  'voice': ['.', ':'],
#  'volume': ['of'],
#  'walking': ['upside'],
#  'wall': [','],
#  'walls': ['and', ','],
#  'was': ['expected',
#   'no',
#   'because',
#   'nothing',
#   'rewarded',
#   'so',
#   'facing',
#   'about',
#   'especially',
#   'upset',
#   'reported',
#   'progressing',
#   'sliding',
#   'likely',
#   'beyond',
#   'revealed',
#   'clearly',
#   'not',
#   'announced',
#   'reported',
#   'noted',
#   'a',
#   'on',
#   'also',
#   'like',
#   'expanding',
#   'futile',
#   'there',
#   'rounded',
#   'superfluous',
#   'merely',
#   'it',
#   'never',
#   'understood',
#   'almost',
#   'driven',
#   'that',
#   'estimated',
#   'abruptly',
#   'turning',
#   'only',
#   'the',
#   'working',
#   'entrusted',
#   'a',
#   'hydrodynamics',
#   'filled',
#   'adrift',
#   'eradicated'],
#  'water': [',', ',', 'if', 'were', 'in'],
#  'weak': ['surface'],
#  'wealthy': ['people', 'people', 'people'],
#  'were': ['returned',
#   'beginning',
#   'radically',
#   'meeting',
#   'times',
#   'diverse',
#   'beginning',
#   'occasionally',
#   'clirnbing',
#   'beginning',
#   'discovered',
#   'the',
#   'especially',
#   'acknowledging',
#   'seen',
#   'optimistic',
#   'sinking',
#   'covered',
#   'beginning',
#   'steadily',
#   'filled',
#   'not',
#   'destroyed'],
#  'what': ['was'],
#  'whatever': ['biological'],
#  'whatsoever': ['on'],
#  'when': ['the', 'this', 'they', 'the'],
#  'whenever': ['they'],
#  'which': ['he', 'was'],
#  'while': ['he', 'property', 'they'],
#  'whiskey': ['is'],
#  'who': ['clearly'],
#  'whom': ['were'],
#  'whose': ['boat'],
#  'wind': ['.'],
#  'windows': ['.'],
#  'with': ['only', 'the', 'descriptions', 'atomic', 'liquid'],
#  'within': ['his', 'the', 'the', 'the'],
#  'without': ['losing'],
#  'withstand': ['the'],
#  'women': ['swimming', 'fainting'],
#  'wonder': ['that'],
#  'words': ['.', 'was'],
#  'worker': ["'s", "'s", '.', '.', 'spread', 'quietly', 'going'],
#  'workers': ['completely', 'needed', 'on'],
#  'working': ['hard'],
#  'world': ['.', 'completely', 'to', '-wide', 'with', '.'],
#  'would': ['discern',
#   'not',
#   'display',
#   'display',
#   'vanish',
#   'not',
#   'expand',
#   'result'],
#  'writhing': ['apples'],
#  'year': ['the'],
#  'you': ['think'],
#  'young': ['women']}

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-86879a7ec606> in <module>()
# ----> 1 from PrepareChain import PrepareChain
#
# ModuleNotFoundError: No module named 'PrepareChain'
